# %% [markdown]
# # How to load and use thermodynamic databases
#
# Reaktoro requires thermodynamic databases to compute thermodynamic properties
# of chemical species and reactions. These properties are needed when performing
# chemical equilibrium and kinetics calculations.
#
# Examples of such thermodynamic properties for a species $i$ include:
#
# * standard molar Gibbs energy, $G_i^\circ$
# * standard molar Helmholtz energy, $A_i^\circ$
# * standard molar enthalpy, $H_i^\circ$
# * standard molar internal energy, $U_i^\circ$
# * standard molar entropy, $S_i^\circ$
# * standard molar volume, $V_i^\circ$
# * standard molar heat capacity (constant pressure), $C_{P,i}^\circ$
# * standard molar heat capacity (constant volume), $C_{V,i}^\circ$
#
# The above standard thermodynamic properties of species can be used to compute
# reaction properties such as the following for a reaction $m$:
#
# * equilibrium constant of reaction, $K_m$
# * standard Gibbs energy of reaction, $\Delta G_m^\circ$
# * standard enthalpy of reaction, $\Delta H_m^\circ$
#
# Currently, Reaktoro supports thermodynamic databases of the following providers:
#
# * [PHREEQC](https://www.usgs.gov/software/phreeqc-version-3)
# * [ThermoFun](https://thermohub.org/thermofun/thermofun/)
# * [SUPCRT](https://www.sciencedirect.com/science/article/pii/009830049290029Q)
# * [SUPCRTBL](https://models.earth.indiana.edu/supcrtbl.php)
# * [NASA](https://www1.grc.nasa.gov/research-and-engineering/ceaweb/)
#
# ```{note}
# This guide demonstrates how a particular thermodynamic database can be accessed
# and inspected using Reaktoro’s Python API. Details of all other supported
# thermodynamic databases in Reaktoro are given in the next section.
# ```
#
# In this guide, we will demonstrate how the [cemdata18](https://www.empa.ch/web/s308/cemdata) database supported in
# ThermoFun can be loaded and inspected programmatically. This is done next by
# creating an object of class {{ThermoFunDatabase}} with the database name of
# interest:

# %%
import reaktoro as rkt
db = rkt.ThermoFunDatabase("cemdata18")

# %% [markdown]
# Let's now loop through all species in this database object and print its name
# and chemical formula:

# %%
print("{:<20}{:<20}".format("Name", "Formula"))
for species in db.species():
    print("{:<20}{:<20}".format(species.name(), species.formula().str()))
# Out:
# Name                Formula
# 5CA                 (CaO)1.25(SiO2)1(Al2O3)0.125(H2O)1.625
# 5CNA                (CaO)1.25(SiO2)1(Al2O3)0.125(Na2O)0.25(H2O)1.375
# Al(SO4)+            Al(SO4)+
# Al(SO4)2-           Al(SO4)2-
# Al+3                Al+3
# AlO+                AlO+
# AlO2-               AlO2-
# AlO2H@              AlO2H@
# AlOH+2              Al(OH)+2
# AlOHam              Al(OH)3
# AlOHmic             Al(OH)3
# AlSiO5-3            AlSiO5-3
# Amor-Sl             SiO2
# Anh                 CaSO4
# Arg                 CaCO3
# Brc                 Mg(OH)2
# C12A7               (CaO)12(Al2O3)7
# C2AClH5             Ca2AlCl(OH)6(H2O)2
# C2AH65              Ca2Al(OH)7(H2O)3
# C2AH7.5             Ca2Al2(OH)10(H2O)2.5
# C2S                 (CaO)2SiO2
# C3A                 (CaO)3Al2O3
# C3AFS0.84H4.32      (AlFe|3|O3)[Ca3O3(SiO2)0.84(H2O)4.32]
# C3AH6               Ca3Al2O6(H2O)6
# C3AS0.41H5.18       Ca3Al2O6(SiO2)0.41(H2O)5.18
# C3AS0.84H4.32       (AlAlO3)[Ca3O3(SiO2)0.84(H2O)4.32]
# C3FH6               Ca3Fe|3|2O6(H2O)6
# C3FS0.84H4.32       (Fe|3|Fe|3|O3)[Ca3O3(SiO2)0.84(H2O)4.32]
# C3FS1.34H3.32       Ca3Fe|3|2O6(SiO2)1.34(H2O)3.32
# C3S                 (CaO)3SiO2
# C4AClH10            Ca4Al2Cl2(OH)12(H2O)4
# C4AF                (CaO)4(Al2O3)(Fe|3|2O3)
# C4AH11              Ca4Al2(OH)14(H2O)4
# C4AH13              Ca4Al2(OH)14(H2O)6
# C4AH19              Ca4Al2(OH)14(H2O)12
# C4AsClH12           Ca4Al2Cl(SO4)0.5(OH)12(H2O)6
# C4FH13              Ca4Fe|3|2(OH)14(H2O)6
# CA                  CaOAl2O3
# CA2                 CaO(Al2O3)2
# CAH10               CaOAl2O3(H2O)10
# CH4                 C|-4|H4
# CH4@                C|-4|H4@
# CO2                 CO2
# CO2@                CO2@
# CO3-2               CO3-2
# CSH3T-T2C           ((CaO)0.75(SiO2)0.5(H2O)1.25)2
# CSH3T-T5C           ((CaO)1(SiO2)1(H2O)2)1.25
# CSH3T-TobH          (CaO)1(SiO2)1.5(H2O)2.5
# CSHQ-JenD           (CaO)1.5(SiO2)0.6667(H2O)2.5
# CSHQ-JenH           (CaO)1.3333(SiO2)1(H2O)2.1667
# CSHQ-TobD           ((CaO)1.25(SiO2)1(H2O)2.75)0.6667
# CSHQ-TobH           (CaO)0.6667(SiO2)1(H2O)1.5
# Ca(CO3)@            CaCO3@
# Ca(HCO3)+           Ca(HCO3)+
# Ca(HSiO3)+          Ca(HSiO3)+
# Ca(SO4)@            CaSO4@
# Ca+2                Ca+2
# CaOH+               Ca(OH)+
# CaSiO3@             CaSiO3@
# Cal                 CaCO3
# Cl-                 Cl-
# ClO4-               Cl|7|O4-
# Cls                 SrSO4
# Dis-Dol             CaMg(CO3)2
# ECSH1-KSH           ((KOH)2.5SiO2H2O)0.2
# ECSH1-NaSH          ((NaOH)2.5SiO2H2O)0.2
# ECSH1-SH            (SiO2H2O)1
# ECSH1-SrSH          ((Sr(OH)2)1SiO2H2O)1
# ECSH1-TobCa         ((Ca(OH)2)0.8333SiO2H2O)1
# ECSH2-JenCa         ((Ca(OH)2)1.6667SiO2H2O)0.6
# ECSH2-KSH           ((KOH)2.5SiO2H2O)0.2
# ECSH2-NaSH          ((NaOH)2.5SiO2H2O)0.2
# ECSH2-SrSH          ((Sr(OH)2)1SiO2H2O)1
# ECSH2-SrSH(ACW)     ((Sr(OH)2)1SiO2H2O)1
# ECSH2-TobCa         ((Ca(OH)2)0.8333SiO2H2O)1
# Ettringite13_des    Ca6Al2(SO4)3(OH)12(H2O)7
# Ettringite9_des     Ca6Al2(SO4)3(OH)12(H2O)3
# Fe                  Fe|0|
# Fe(CO3)@            FeCO3@
# Fe(HCO3)+           FeHCO3+
# Fe(HSO4)+           FeHSO4+
# Fe(HSO4)+2          Fe|3|HSO4+2
# Fe(SO4)+            Fe|3|(SO4)+
# Fe(SO4)2-           Fe|3|(SO4)2-
# Fe(SO4)@            Fe(SO4)@
# Fe+2                Fe+2
# Fe+3                Fe|3|+3
# Fe-ettringite       Ca6Fe|3|2(SO4)3(OH)12(H2O)26
# Fe-ettringite05     Ca3Fe|3|(SO4)1.5(OH)6(H2O)13
# Fe-hemicarbonate    Ca3O3Fe|3|2O3(CaCO3)0.5(CaO2H2)0.5(H2O)9.5
# Fe-monosulph05      Ca2Fe|3|S0.5O5(H2O)6
# Fe-monosulphate     Ca4Fe|3|2SO10(H2O)12
# FeCl+               FeCl+
# FeCl+2              Fe|3|Cl+2
# FeCl2+              Fe|3|Cl2+
# FeCl3@              Fe|3|Cl3@
# FeO+                Fe|3|O+
# FeO2-               Fe|3|O2-
# FeO2H@              Fe|3|O2H@
# FeOH+               FeOH+
# FeOH+2              Fe|3|(OH)+2
# FeOOHmic            Fe|3|OOH
# Femonocarbonate     Ca4O4Fe|3|2O3CO2(H2O)12
# Gbs                 Al(OH)3
# Gp                  CaSO4(H2O)2
# Gr                  C|0|
# Gt                  Fe|3|O(OH)
# H+                  H+
# H2                  H|0|2
# H2@                 H|0|2@
# H2O                 H2O
# H2O@                H2O@
# H2S                 H2S|-2|
# H2S@                H2S|-2|@
# HCN@                HC|-1|N|0|@
# HCO3-               HCO3-
# HS-                 HS|-2|-
# HSO3-               HS|4|O3-
# HSO4-               HS|6|O4-
# HSiO3-              HSiO3-
# Hem                 Fe|3|2O3
# INFCA               (CaO)1(SiO2)1.1875(Al2O3)0.15625(H2O)1.65625
# INFCN               (CaO)1(SiO2)1.5(Na2O)0.3125(H2O)1.1875
# INFCNA              (CaO)1(SiO2)1.1875(Al2O3)0.15625(Na2O)0.34375(H2O)1.3125
# Jennite             (SiO2)1(CaO)1.666667(H2O)2.1
# K(SO4)-             KSO4-
# K+                  K+
# K2O                 K2O
# K2SO4               K2SO4
# KOH@                KOH@
# KSiOH               ((KOH)2.5SiO2H2O)0.2
# Kln                 Al2Si2O5(OH)4
# Lim                 CaO
# M075SH              Mg1.5Si2O5.5(H2O)2.5
# M15SH               Mg1.5SiO3.5(H2O)2.5
# M4A-OH-LDH          Mg4Al2(OH)14(H2O)3
# M6A-OH-LDH          Mg6Al2(OH)18(H2O)3
# M8A-OH-LDH          Mg8Al2(OH)22(H2O)3
# Mag                 FeFe|3|2O4
# Melanterite         FeSO4(H2O)7
# Mg(CO3)@            Mg(CO3)@
# Mg(HCO3)+           Mg(HCO3)+
# Mg(HSiO3)+          Mg(HSiO3)+
# Mg+2                Mg+2
# Mg2AlC0.5OH         Mg2Al(OH)6(CO3)0.5(H2O)2
# Mg2FeC0.5OH         Mg2Fe|3|(OH)6(CO3)0.5(H2O)2
# Mg3AlC0.5OH         Mg3Al(OH)8(CO3)0.5(H2O)2.5
# Mg3FeC0.5OH         Mg3Fe|3|(OH)8(CO3)0.5(H2O)2.5
# MgOH+               Mg(OH)+
# MgSO4@              Mg(SO4)@
# Mgs                 MgCO3
# N2                  N|0|2
# N2@                 N|0|2@
# NH3@                N|-3|H3@
# NH4+                N|-3|H4+
# NO3-                NO3-
# Na(CO3)-            NaCO3-
# Na(HCO3)@           NaHCO3@
# Na(SO4)-            Na(SO4)-
# Na+                 Na+
# Na2O                Na2O
# Na2SO4              Na2SO4
# NaOH@               NaOH@
# NaSiOH              ((NaOH)2.5SiO2H2O)0.2
# O2                  O|0|2
# O2@                 O|0|2@
# OH-                 OH-
# Ord-Dol             CaMg(CO3)2
# Portlandite         Ca(OH)2
# Py                  FeS|0|S|-2|
# Qtz                 SiO2
# S2O3-2              S|2|2O3-2
# SCN-                S|0|C|0|N|-1|-
# SO3-2               S|4|O3-2
# SO4-2               S|6|O4-2
# Sd                  FeCO3
# Si4O10-4            Si4O10-4
# SiO2@               SiO2@
# SiO3-2              SiO3-2
# Sr(CO3)@            Sr(CO3)@
# Sr(HCO3)+           SrHCO3+
# Sr(SO4)@            Sr(SO4)@
# Sr+2                Sr+2
# SrOH+               Sr(OH)+
# SrSiO3@             SrSiO3@
# Str                 SrCO3
# Sulfur              S|0|
# T2C-CNASHss         (CaO)1.5(SiO2)1(H2O)2.5
# T5C-CNASHss         (CaO)1.25(SiO2)1.25(H2O)2.5
# Tob-I               (SiO2)2.4(CaO)2(H2O)3.2
# Tob-II              (SiO2)1(CaO)0.833333(H2O)1.333333
# TobH-CNASHss        (CaO)1(SiO2)1.5(H2O)2.5
# Tro                 Fe|2|S|-2|
# chabazite           Ca(Al2Si4)O12(H2O)6
# ettringite          ((H2O)2)Ca6Al2(SO4)3(OH)12(H2O)24
# ettringite03_ss     (SO4)Ca2Al0.6666667(OH)4(H2O)8.6666667
# ettringite05        Ca3Al(SO4)1.5(OH)6(H2O)13
# ettringite13        Ca6Al2(SO4)3(OH)12(H2O)7
# ettringite30        Ca6Al2(SO4)3(OH)12(H2O)24
# ettringite9         Ca6Al2(SO4)3(OH)12(H2O)3
# ettringite_ss       {SO4}3:Ca6Al2(OH)12(H2O)26
# hemicarbonat10.5    (CaO)3Al2O3(CaCO3)0.5(CaO2H2)0.5(H2O)10
# hemicarbonate       (CaO)3Al2O3(CaCO3)0.5(CaO2H2)0.5(H2O)11.5
# hemicarbonate9      (CaO)3Al2O3(CaCO3)0.5(CaO2H2)0.5(H2O)8.5
# hemihydrate         CaSO4(H2O)0.5
# hydrotalcite        Mg4Al2O7(H2O)10
# monocarbonate       Ca4Al2CO9(H2O)11
# monocarbonate05     Ca2AlC0.5O4.5(H2O)5.5
# monocarbonate9      Ca4Al2CO9(H2O)9
# mononitrate         Ca4Al2(OH)12N|5|2O6(H2O)4
# mononitrite         Ca4Al2(OH)12N|3|2O4(H2O)4
# monosulphate10.5    Ca4Al2SO10(H2O)10.5
# monosulphate12      Ca4Al2SO10(H2O)12
# monosulphate1205    Ca2AlS0.5O5(H2O)6
# monosulphate14      Ca4Al2SO10(H2O)14
# monosulphate16      Ca4Al2SO10(H2O)16
# monosulphate9       Ca4Al2SO10(H2O)9
# natrolite           Na2(Al2Si3)O10(H2O)2
# straetlingite       Ca2Al2SiO7(H2O)8
# straetlingite5.5    Ca2Al2SiO7(H2O)5.5
# straetlingite7      Ca2Al2SiO7(H2O)7
# syngenite           K2Ca(SO4)2H2O
# thaumasite          (CaSiO3)(CaSO4)(CaCO3)(H2O)15
# tricarboalu         {CO3}3:Ca6Al2(OH)12(H2O)26
# tricarboalu03       (CO3)Ca2Al0.6666667(OH)4(H2O)8.6666667
# zeoliteP_Ca         Ca(Al2Si2)O8(H2O)4.5
# zeoliteX            Na2(Al2Si2.5)O9(H2O)6.2
# zeoliteY            Na2(Al2Si4)O12(H2O)8

# %% [markdown]
# Let's now use the `Database.species` method to obtain the list of species in
# the database (and object of class {{SpeciesList}}) and then filter out all
# species that are not composed of chemical elements H, O, C, and Ca (using
# method `SpeciesList.withElements`):

# %%
for species in db.species().withElements("H O C Ca"):
    print(species.name())
# Out:
# Arg
# CH4
# CH4@
# CO2
# CO2@
# CO3-2
# Ca(CO3)@
# Ca(HCO3)+
# Ca+2
# CaOH+
# Cal
# Gr
# H+
# H2
# H2@
# H2O
# H2O@
# HCO3-
# Lim
# O2
# O2@
# OH-
# Portlandite

# %% [markdown]
# For more usage possibilities, check the full API of the {{Database}} class as well as classes {{Species}} and {{Element}} in the links below:
#
# * [{{Database}}](https://reaktoro.org/api/classReaktoro_1_1Database.html)
# * [{{Species}}](https://reaktoro.org/api/classReaktoro_1_1Species.html)
# * [{{Element}}](https://reaktoro.org/api/classReaktoro_1_1Element.html)
#
# The next section details all other supported thermodynamic database providers.
